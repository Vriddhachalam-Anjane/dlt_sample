# %%
print('he')
# Out:
# he

# %%
pip install --upgrade duckdb
# Out:
# Collecting duckdb
#   Downloading duckdb-1.2.1-cp312-cp312-win_amd64.whl.metadata (995 bytes)
# Downloading duckdb-1.2.1-cp312-cp312-win_amd64.whl (11.4 MB)
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    -------------- ------------------------- 4.2/11.4 MB 28.1 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.4 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.4/11.4 MB 24.5 MB/s eta 0:00:00
# Installing collected packages: duckdb
# Successfully installed duckdb-1.2.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import duckdb

# Connect to the DuckDB file (provide the file path to the .duckdb file)
conn = duckdb.connect("./github_events.duckdb")

# Execute a query on the database
query = "select * from github_events_data.pull_request_event"  # Replace with your SQL query
result = conn.execute(query).fetchall()

# Print the query result
print(result)
# print("Tables in the database:")
# for table in result:
#     print(table[0])  #

# Close the connection
conn.close()
# Out:
# [('46772761967', 'PullRequestEvent', 126648889, 'Vriddhachalam-Anjane', 'Vriddhachalam-Anjane', '', 'https://api.github.com/users/Vriddhachalam-Anjane', 'https://avatars.githubusercontent.com/u/126648889?', 738910210, 'Vriddhachalam-Anjane/dbt_self_for_django', 'https://api.github.com/repos/Vriddhachalam-Anjane/dbt_self_for_django', 'reopened', 24, 'https://api.github.com/repos/Vriddhachalam-Anjane/dbt_self_for_django/pulls/24', 2339533018, 'PR_kwDOLArgAs6LcnDa', 'https://github.com/Vriddhachalam-Anjane/dbt_self_for_django/pull/24', 'https://github.com/Vriddhachalam-Anjane/dbt_self_for_django/pull/24.diff', 'https://github.com/Vriddhachalam-Anjane/dbt_self_for_django/pull/24.patch', 'https://api.github.com/repos/Vriddhachalam-Anjane/dbt_self_for_django/issues/24', 24, 'open', False, 'Env var', 'Vriddhachalam-Anjane', 126648889, 'U_kgDOB4yCOQ', 'https://avatars.githubusercontent.com/u/126648889?v=4', '', 'https://api.github.com/users/Vriddhachalam-Anjane', 'https://github.com/Vriddhachalam-Anjane', 'https://api.github.com/users/Vriddhachalam-Anjane/followers', 'https://api.github.com/users/Vriddhachalam-Anjane/following{/other_user}', 'https://api.github.com/users/Vriddhachalam-Anjane/gists{/gist_id}', 'https://api.github.com/users/Vriddhachalam-Anjane/starred{/owner}{/repo}', 'https://api.github.com/users/Vriddhachalam-Anjane/subscriptions', 'https://api.github.com/users/Vriddhachalam-Anjane/orgs', 'https://api.github.com/users/Vriddhachalam-Anjane/repos', 'https://api.github.com/users/Vriddhachalam-Anjane/events{/privacy}', 'https://api.github.com/users/Vriddhachalam-Anjane/received_events', 'User', 'public', False, datetime.datetime(2025, 2, 17, 17, 14, 6, tzinfo=<DstTzInfo 'Asia/Calcutta' IST+5:30:00 STD>), datetime.datetime(2025, 2, 20, 16, 50, 33, tzinfo=<DstTzInfo 'Asia/Calcutta' IST+5:30:00 STD>), False, 'https://api.github.com/repos/Vriddhachalam-Anjane/dbt_self_for_django/pulls/24/commits', 'https://api.github.com/repos/Vriddhachalam-Anjane/dbt_self_for_django/pulls/24/comments', 'https://api.github.com/repos/Vriddhachalam-Anjane/dbt_self_for_django/pulls/comments{/number}', 'https://api.github.com/repos/Vriddhachalam-Anjane/dbt_self_for_django/issues/24/comments', 'https://api.github.com/repos/Vriddhachalam-Anjane/dbt_self_for_django/statuses/b76a9d785e25dd88f8bf20519e7331fbb835fbd8', 'Vriddhachalam-Anjane:env_var', 'env_var', 'b76a9d785e25dd88f8bf20519e7331fbb835fbd8', 'Vriddhachalam-Anjane', 126648889, 'U_kgDOB4yCOQ', 'https://avatars.githubusercontent.com/u/126648889?v=4', '', 'https://api.github.com/users/Vriddhachalam-Anjane', 'https://github.com/Vriddhachalam-Anjane', 'https://api.github.com/users/Vriddhachalam-Anjane/followers', 'https://api.github.com/users/Vriddhachalam-Anjane/following{/other_user}', 'https://api.github.com/users/Vriddhachalam-Anjane/gists{/gist_id}', 'https://api.github.com/users/Vriddhachalam-Anjane/starred{/owner}{/repo}', 'https://api.github.com/users/Vriddhachalam-Anjane/subscriptions', 'https://api.github.com/users/Vriddhachalam-Anjane/orgs', 'https://api.github.com/users/Vriddhachalam-Anjane/repos', 'https://api.github.com/users/Vriddhachalam-Anjane/events{/privacy}', 'https://api.github.com/users/Vriddhachalam-Anjane/received_events', 'User', 'public', False, 738910210, 'R_kgDOLArgAg', 'dbt_self_for_django', 'Vriddhachalam-Anjane/dbt_self_for_django', True, 'Vriddhachalam-Anjane', 126648889, 'U_kgDOB4yCOQ', 'https://avatars.githubusercontent.com/u/126648889?v=4', '', 'https://api.github.com/users/Vriddhachalam-Anjane', 'https://github.com/Vriddhachalam-Anjane', 'https://api.github.com/users/Vriddhachalam-Anjane/followers', 'https://api.github.com/users/Vriddhachalam-Anjane/following{/other_user}', 'https://api.github.com/users/Vriddhachalam-Anjane/gists{/gist_id}', 'https://api.github.com/users/Vriddhachalam-Anjane/starred{/owner}{/repo}', 'https://api.github.com/users/Vriddhachalam-Anjane/subscriptions', 'https://api.github.com/users/Vriddhachalam-Anjane/orgs', 'https://api.github. ...
